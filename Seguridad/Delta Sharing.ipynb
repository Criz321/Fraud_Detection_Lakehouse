-- %%
CREATE SHARE DATA_MART_SHARE
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>info_name</th><th>info_value</th></tr></thead><tbody><tr><td>share_name</td><td>data_mart_share</td></tr><tr><td>owner</td><td>anthony.dev00@hotmail.com</td></tr><tr><td>created_at</td><td>2026-07-17 18:57:16.588</td></tr><tr><td>created_by</td><td>anthony.dev00@hotmail.com</td></tr><tr><td>updated_at</td><td>2026-07-17 18:57:16.588</td></tr><tr><td>updated_by</td><td>anthony.dev00@hotmail.com</td></tr><tr><td>comment</td><td></td></tr></tbody></table></div>

-- %%
ALTER SHARE DATA_MART_SHARE
ADD TABLE bank_dev.gold.fraud_transaction_datamart
WITH HISTORY
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
CREATE RECIPIENT ExternalCompanys
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
GRANT SELECT
ON SHARE DATA_MART_SHARE
TO RECIPIENT ExternalCompanys
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
