-- %%
%python
dbutils.widgets.removeAll()

-- %%
DESCRIBE HISTORY bank_dev.silver.transactions
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * 
FROM `bank_dev`.`silver`.`transactions` VERSION AS OF 2
LIMIT 100;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
RESTORE TABLE `bank_dev`.`silver`.`transactions` TO VERSION AS OF 5;

-- %%
SELECT COUNT(*) AS total_registros 
FROM `bank_dev`.`silver`.`transactions`;
